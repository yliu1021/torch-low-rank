# %%
from glob import glob
import json
import pandas as pd
import numpy as np

# %%
results = [json.load(open(f)) for f in glob("set_rank_results_cifar10/*.json")]
results = pd.DataFrame(results)

results["best_loss"] = results["loss"].map(np.min)
results["best_loss_epoch"] = results["loss"].map(lambda x: np.argmin(x) + 1)
results["best_categorical_accuracy"] = results["categorical_accuracy"].map(np.max)
results["best_categorical_accuracy_epoch"] = results["categorical_accuracy"].map(lambda x: np.argmax(x) + 1)
results["best_val_loss"] = results["val_loss"].map(np.min)
results["best_val_loss_epoch"] = results["val_loss"].map(lambda x: np.argmin(x) + 1)
results["best_val_categorical_accuracy"] = results["val_categorical_accuracy"].map(np.max)
results["best_val_categorical_accuracy_epoch"] = results["val_categorical_accuracy"].map(lambda x: np.argmax(x) + 1)
results["initial_rank"].replace(-1, 256, inplace=True)
results["new_rank"].replace(-1, 256, inplace=True)
results.head()
# Out:
#    initial_rank  new_rank  rank_update_epoch  total_epochs  \
# 0           200        14                 10            50
# 1           256        53                 25            50
# 2             1        14                  2            50
# 3           256        53                 25            50
# 4            53       256                  5            50
#
#                                                 loss  \
# 0  [1.6943475008010864, 1.3511114120483398, 1.194...
# 1  [1.6889116764068604, 1.363222360610962, 1.2238...
# 2  [2.008345365524292, 1.8717670440673828, 1.6404...
# 3  [1.6964704990386963, 1.3796123266220093, 1.238...
# 4  [1.7248677015304565, 1.4034148454666138, 1.257...
#
#                                 categorical_accuracy  \
# 0  [0.37577998638153076, 0.5093200206756592, 0.57...
# 1  [0.37882000207901, 0.5082399845123291, 0.56260...
# 2  [0.1775200068950653, 0.2021999955177307, 0.358...
# 3  [0.38141998648643494, 0.49987998604774475, 0.5...
# 4  [0.36037999391555786, 0.48594000935554504, 0.5...
#
#                                             val_loss  \
# 0  [1.4911612272262573, 1.366654396057129, 1.1663...
# 1  [1.4815499782562256, 1.3108307123184204, 1.184...
# 2  [1.8917927742004395, 1.8449923992156982, 1.522...
# 3  [1.479851484298706, 1.2734463214874268, 1.1835...
# 4  [1.5207701921463013, 1.323439598083496, 1.1983...
#
#                             val_categorical_accuracy  pre_update_loss  \
# 0  [0.4528999924659729, 0.5027999877929688, 0.573...         0.731901
# 1  [0.47040000557899475, 0.5213000178337097, 0.57...         0.225114
# 2  [0.19269999861717224, 0.20659999549388885, 0.4...         1.846736
# 3  [0.45910000801086426, 0.5455999970436096, 0.57...         0.283592
# 4  [0.43720000982284546, 0.517300009727478, 0.566...         1.010023
#
#    pre_update_categorical_accuracy  ...  post_update_val_loss  \
# 0                          0.74680  ...              0.864800
# 1                          0.92738  ...              0.784675
# 2                          0.20748  ...              1.844984
# 3                          0.90522  ...              0.733720
# 4                          0.63942  ...              1.039510
#
#    post_update_val_categorical_accuracy  best_loss  best_loss_epoch  \
# 0                                0.7045   0.009646               50
# 1                                0.7653   0.019536               46
# 2                                0.2063   0.068689               50
# 3                                0.7678   0.025703               49
# 4                                0.6325   0.009879               49
#
#    best_categorical_accuracy  best_categorical_accuracy_epoch  best_val_loss  \
# 0                    0.99772                               50       0.702425
# 1                    0.99490                               46       0.705935
# 2                    0.97712                               50       0.814391
# 3                    0.99254                               49       0.686433
# 4                    0.99844                               49       0.672208
#
#    best_val_loss_epoch  best_val_categorical_accuracy  \
# 0                   16                         0.7842
# 1                   19                         0.7748
# 2                   25                         0.7440
# 3                   21                         0.7781
# 4                   20                         0.7818
#
#    best_val_categorical_accuracy_epoch
# 0                                   50
# 1                                   50
# 2                                   30
# 3                                   32
# 4                                   25
#
# [5 rows x 24 columns]

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 24 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   initial_rank                          114 non-null    int64
#  1   new_rank                              114 non-null    int64
#  2   rank_update_epoch                     114 non-null    int64
#  3   total_epochs                          114 non-null    int64
#  4   loss                                  114 non-null    object
#  5   categorical_accuracy                  114 non-null    object
#  6   val_loss                              114 non-null    object
#  7   val_categorical_accuracy              114 non-null    object
#  8   pre_update_loss                       114 non-null    float64
#  9   pre_update_categorical_accuracy       114 non-null    float64
#  10  pre_update_val_loss                   114 non-null    float64
#  11  pre_update_val_categorical_accuracy   114 non-null    float64
#  12  post_update_loss                      114 non-null    float64
#  13  post_update_categorical_accuracy      114 non-null    float64
#  14  post_update_val_loss                  114 non-null    float64
#  15  post_update_val_categorical_accuracy  114 non-null    float64
#  16  best_loss                             114 non-null    float64
#  17  best_loss_epoch                       114 non-null    int64
#  18  best_categorical_accuracy             114 non-null    float64
#  19  best_categorical_accuracy_epoch       114 non-null    int64
#  20  best_val_loss                         114 non-null    float64
#  21  best_val_loss_epoch                   114 non-null    int64
#  22  best_val_categorical_accuracy         114 non-null    float64
#  23  best_val_categorical_accuracy_epoch   114 non-null    int64
# dtypes: float64(12), int64(8), object(4)
# memory usage: 21.5+ KB

# %%
np.argmax(results["best_val_categorical_accuracy"])
# Out:
# 29

# %%
results.iloc[29]
# Out:
# initial_rank                                                                          256
# new_rank                                                                              256
# rank_update_epoch                                                                       1
# total_epochs                                                                           50
# loss                                    [1.696595311164856, 1.3655939102172852, 1.2236...
# categorical_accuracy                    [0.3770799934864044, 0.505020022392273, 0.5625...
# val_loss                                [1.4686557054519653, 1.2875036001205444, 1.172...
# val_categorical_accuracy                [0.4708000123500824, 0.5331000089645386, 0.579...
# pre_update_loss                                                                  1.472105
# pre_update_categorical_accuracy                                                   0.47014
# pre_update_val_loss                                                              1.468609
# pre_update_val_categorical_accuracy                                                0.4709
# post_update_loss                                                                 1.472105
# post_update_categorical_accuracy                                                  0.47014
# post_update_val_loss                                                             1.468609
# post_update_val_categorical_accuracy                                               0.4709
# best_loss                                                                        0.023578
# best_loss_epoch                                                                        48
# best_categorical_accuracy                                                         0.99358
# best_categorical_accuracy_epoch                                                        48
# best_val_loss                                                                    0.671406
# best_val_loss_epoch                                                                    17
# best_val_categorical_accuracy                                                      0.7905
# best_val_categorical_accuracy_epoch                                                    26
# Name: 29, dtype: object

# %%
display(results["initial_rank"].unique())
display(results["new_rank"].unique())
display(results["rank_update_epoch"].unique())
# Out:
# array([200, 256,   1,  53,   4,  14])
# array([ 14,  53, 256,   1,   4, 200])
# array([10, 25,  2,  5,  1])

# %%
def visualize(column: str, rank_update_epoch: int):
    avg_results = pd.pivot_table(
        results.loc[
            results["rank_update_epoch"] == rank_update_epoch,
            ["initial_rank", "new_rank", column]
        ],
        index="initial_rank",
        columns="new_rank",
    )
    display(
        avg_results
            .style
            .background_gradient(cmap='Blues')
            .format("{:.3f}")
    )

# %%
for rank_update_epoch in np.sort(results["rank_update_epoch"].unique()):
    print(f"Rank updated on epoch: {rank_update_epoch}")
    visualize("best_val_categorical_accuracy", rank_update_epoch)
# Out:
# Rank updated on epoch: 1
# <style type="text/css">
# #T_8ccf5_row0_col0 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_8ccf5_row0_col1, #T_8ccf5_row0_col4, #T_8ccf5_row2_col3, #T_8ccf5_row3_col0, #T_8ccf5_row3_col5, #T_8ccf5_row4_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8ccf5_row0_col2, #T_8ccf5_row0_col3, #T_8ccf5_row0_col5, #T_8ccf5_row1_col2, #T_8ccf5_row1_col3, #T_8ccf5_row1_col4, #T_8ccf5_row1_col5, #T_8ccf5_row2_col0, #T_8ccf5_row2_col1, #T_8ccf5_row3_col1, #T_8ccf5_row3_col2, #T_8ccf5_row3_col4, #T_8ccf5_row4_col0, #T_8ccf5_row4_col1, #T_8ccf5_row4_col4, #T_8ccf5_row4_col5, #T_8ccf5_row5_col2, #T_8ccf5_row5_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_8ccf5_row1_col0 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_8ccf5_row1_col1 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_8ccf5_row2_col2, #T_8ccf5_row2_col4, #T_8ccf5_row3_col3, #T_8ccf5_row5_col0, #T_8ccf5_row5_col1, #T_8ccf5_row5_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8ccf5_row2_col5 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_8ccf5_row4_col3 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_8ccf5_row5_col3 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8ccf5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="6">best_val_categorical_accuracy</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >new_rank</th>
#       <th class="col_heading level1 col0" >1</th>
#       <th class="col_heading level1 col1" >4</th>
#       <th class="col_heading level1 col2" >14</th>
#       <th class="col_heading level1 col3" >53</th>
#       <th class="col_heading level1 col4" >200</th>
#       <th class="col_heading level1 col5" >256</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >initial_rank</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ccf5_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8ccf5_row0_col0" class="data row0 col0" >0.465</td>
#       <td id="T_8ccf5_row0_col1" class="data row0 col1" >0.715</td>
#       <td id="T_8ccf5_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_8ccf5_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_8ccf5_row0_col4" class="data row0 col4" >0.772</td>
#       <td id="T_8ccf5_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8ccf5_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_8ccf5_row1_col0" class="data row1 col0" >0.466</td>
#       <td id="T_8ccf5_row1_col1" class="data row1 col1" >0.731</td>
#       <td id="T_8ccf5_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_8ccf5_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_8ccf5_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_8ccf5_row1_col5" class="data row1 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8ccf5_level0_row2" class="row_heading level0 row2" >14</th>
#       <td id="T_8ccf5_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_8ccf5_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_8ccf5_row2_col2" class="data row2 col2" >0.783</td>
#       <td id="T_8ccf5_row2_col3" class="data row2 col3" >0.777</td>
#       <td id="T_8ccf5_row2_col4" class="data row2 col4" >0.774</td>
#       <td id="T_8ccf5_row2_col5" class="data row2 col5" >0.779</td>
#     </tr>
#     <tr>
#       <th id="T_8ccf5_level0_row3" class="row_heading level0 row3" >53</th>
#       <td id="T_8ccf5_row3_col0" class="data row3 col0" >0.459</td>
#       <td id="T_8ccf5_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_8ccf5_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_8ccf5_row3_col3" class="data row3 col3" >0.785</td>
#       <td id="T_8ccf5_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_8ccf5_row3_col5" class="data row3 col5" >0.777</td>
#     </tr>
#     <tr>
#       <th id="T_8ccf5_level0_row4" class="row_heading level0 row4" >200</th>
#       <td id="T_8ccf5_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_8ccf5_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_8ccf5_row4_col2" class="data row4 col2" >0.776</td>
#       <td id="T_8ccf5_row4_col3" class="data row4 col3" >0.785</td>
#       <td id="T_8ccf5_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_8ccf5_row4_col5" class="data row4 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8ccf5_level0_row5" class="row_heading level0 row5" >256</th>
#       <td id="T_8ccf5_row5_col0" class="data row5 col0" >0.476</td>
#       <td id="T_8ccf5_row5_col1" class="data row5 col1" >0.739</td>
#       <td id="T_8ccf5_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_8ccf5_row5_col3" class="data row5 col3" >0.781</td>
#       <td id="T_8ccf5_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_8ccf5_row5_col5" class="data row5 col5" >0.790</td>
#     </tr>
#   </tbody>
# </table>
# Rank updated on epoch: 2
# <style type="text/css">
# #T_07f76_row0_col0, #T_07f76_row0_col1, #T_07f76_row1_col0, #T_07f76_row1_col2, #T_07f76_row1_col3, #T_07f76_row1_col4, #T_07f76_row2_col2, #T_07f76_row2_col4, #T_07f76_row2_col5, #T_07f76_row3_col0, #T_07f76_row3_col1, #T_07f76_row3_col3, #T_07f76_row4_col0, #T_07f76_row4_col1, #T_07f76_row4_col2, #T_07f76_row4_col4, #T_07f76_row5_col3, #T_07f76_row5_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_07f76_row0_col2, #T_07f76_row0_col3, #T_07f76_row0_col4, #T_07f76_row1_col1, #T_07f76_row1_col5, #T_07f76_row2_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_07f76_row0_col5, #T_07f76_row2_col1, #T_07f76_row3_col4, #T_07f76_row4_col3, #T_07f76_row5_col0, #T_07f76_row5_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_07f76_row2_col3 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_07f76_row3_col2 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_07f76_row3_col5 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_07f76_row4_col5 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_07f76_row5_col1 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_07f76_row5_col5 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_07f76_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="6">best_val_categorical_accuracy</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >new_rank</th>
#       <th class="col_heading level1 col0" >1</th>
#       <th class="col_heading level1 col1" >4</th>
#       <th class="col_heading level1 col2" >14</th>
#       <th class="col_heading level1 col3" >53</th>
#       <th class="col_heading level1 col4" >200</th>
#       <th class="col_heading level1 col5" >256</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >initial_rank</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07f76_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_07f76_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_07f76_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_07f76_row0_col2" class="data row0 col2" >0.744</td>
#       <td id="T_07f76_row0_col3" class="data row0 col3" >0.755</td>
#       <td id="T_07f76_row0_col4" class="data row0 col4" >0.771</td>
#       <td id="T_07f76_row0_col5" class="data row0 col5" >0.784</td>
#     </tr>
#     <tr>
#       <th id="T_07f76_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_07f76_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_07f76_row1_col1" class="data row1 col1" >0.736</td>
#       <td id="T_07f76_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_07f76_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_07f76_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_07f76_row1_col5" class="data row1 col5" >0.777</td>
#     </tr>
#     <tr>
#       <th id="T_07f76_level0_row2" class="row_heading level0 row2" >14</th>
#       <td id="T_07f76_row2_col0" class="data row2 col0" >0.487</td>
#       <td id="T_07f76_row2_col1" class="data row2 col1" >0.740</td>
#       <td id="T_07f76_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_07f76_row2_col3" class="data row2 col3" >0.780</td>
#       <td id="T_07f76_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_07f76_row2_col5" class="data row2 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_07f76_level0_row3" class="row_heading level0 row3" >53</th>
#       <td id="T_07f76_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_07f76_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_07f76_row3_col2" class="data row3 col2" >0.777</td>
#       <td id="T_07f76_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_07f76_row3_col4" class="data row3 col4" >0.780</td>
#       <td id="T_07f76_row3_col5" class="data row3 col5" >0.779</td>
#     </tr>
#     <tr>
#       <th id="T_07f76_level0_row4" class="row_heading level0 row4" >200</th>
#       <td id="T_07f76_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_07f76_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_07f76_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_07f76_row4_col3" class="data row4 col3" >0.783</td>
#       <td id="T_07f76_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_07f76_row4_col5" class="data row4 col5" >0.784</td>
#     </tr>
#     <tr>
#       <th id="T_07f76_level0_row5" class="row_heading level0 row5" >256</th>
#       <td id="T_07f76_row5_col0" class="data row5 col0" >0.547</td>
#       <td id="T_07f76_row5_col1" class="data row5 col1" >0.739</td>
#       <td id="T_07f76_row5_col2" class="data row5 col2" >0.782</td>
#       <td id="T_07f76_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_07f76_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_07f76_row5_col5" class="data row5 col5" >0.781</td>
#     </tr>
#   </tbody>
# </table>
# Rank updated on epoch: 5
# <style type="text/css">
# #T_bc8e5_row0_col0, #T_bc8e5_row0_col2, #T_bc8e5_row1_col2, #T_bc8e5_row1_col3, #T_bc8e5_row1_col4, #T_bc8e5_row1_col5, #T_bc8e5_row2_col2, #T_bc8e5_row3_col1, #T_bc8e5_row3_col2, #T_bc8e5_row4_col2, #T_bc8e5_row5_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_bc8e5_row0_col1, #T_bc8e5_row0_col3, #T_bc8e5_row0_col4, #T_bc8e5_row1_col0, #T_bc8e5_row1_col1, #T_bc8e5_row2_col1, #T_bc8e5_row2_col3, #T_bc8e5_row2_col4, #T_bc8e5_row3_col0, #T_bc8e5_row3_col3, #T_bc8e5_row4_col0, #T_bc8e5_row4_col1, #T_bc8e5_row4_col4, #T_bc8e5_row5_col0, #T_bc8e5_row5_col3, #T_bc8e5_row5_col4, #T_bc8e5_row5_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_bc8e5_row0_col5, #T_bc8e5_row4_col5 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_bc8e5_row2_col0, #T_bc8e5_row2_col5, #T_bc8e5_row3_col4, #T_bc8e5_row4_col3, #T_bc8e5_row5_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_bc8e5_row3_col5 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bc8e5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="6">best_val_categorical_accuracy</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >new_rank</th>
#       <th class="col_heading level1 col0" >1</th>
#       <th class="col_heading level1 col1" >4</th>
#       <th class="col_heading level1 col2" >14</th>
#       <th class="col_heading level1 col3" >53</th>
#       <th class="col_heading level1 col4" >200</th>
#       <th class="col_heading level1 col5" >256</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >initial_rank</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc8e5_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_bc8e5_row0_col0" class="data row0 col0" >0.452</td>
#       <td id="T_bc8e5_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_bc8e5_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_bc8e5_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_bc8e5_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_bc8e5_row0_col5" class="data row0 col5" >0.779</td>
#     </tr>
#     <tr>
#       <th id="T_bc8e5_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_bc8e5_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_bc8e5_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_bc8e5_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_bc8e5_row1_col3" class="data row1 col3" >0.779</td>
#       <td id="T_bc8e5_row1_col4" class="data row1 col4" >0.774</td>
#       <td id="T_bc8e5_row1_col5" class="data row1 col5" >0.778</td>
#     </tr>
#     <tr>
#       <th id="T_bc8e5_level0_row2" class="row_heading level0 row2" >14</th>
#       <td id="T_bc8e5_row2_col0" class="data row2 col0" >0.583</td>
#       <td id="T_bc8e5_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_bc8e5_row2_col2" class="data row2 col2" >0.775</td>
#       <td id="T_bc8e5_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_bc8e5_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_bc8e5_row2_col5" class="data row2 col5" >0.783</td>
#     </tr>
#     <tr>
#       <th id="T_bc8e5_level0_row3" class="row_heading level0 row3" >53</th>
#       <td id="T_bc8e5_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_bc8e5_row3_col1" class="data row3 col1" >0.736</td>
#       <td id="T_bc8e5_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_bc8e5_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_bc8e5_row3_col4" class="data row3 col4" >0.781</td>
#       <td id="T_bc8e5_row3_col5" class="data row3 col5" >0.781</td>
#     </tr>
#     <tr>
#       <th id="T_bc8e5_level0_row4" class="row_heading level0 row4" >200</th>
#       <td id="T_bc8e5_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_bc8e5_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_bc8e5_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_bc8e5_row4_col3" class="data row4 col3" >0.780</td>
#       <td id="T_bc8e5_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_bc8e5_row4_col5" class="data row4 col5" >0.779</td>
#     </tr>
#     <tr>
#       <th id="T_bc8e5_level0_row5" class="row_heading level0 row5" >256</th>
#       <td id="T_bc8e5_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_bc8e5_row5_col1" class="data row5 col1" >0.739</td>
#       <td id="T_bc8e5_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_bc8e5_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_bc8e5_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_bc8e5_row5_col5" class="data row5 col5" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Rank updated on epoch: 10
# <style type="text/css">
# #T_ef8fc_row0_col0, #T_ef8fc_row0_col3, #T_ef8fc_row1_col0, #T_ef8fc_row1_col1, #T_ef8fc_row1_col2, #T_ef8fc_row2_col0, #T_ef8fc_row3_col0, #T_ef8fc_row4_col0, #T_ef8fc_row4_col5, #T_ef8fc_row5_col0, #T_ef8fc_row5_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ef8fc_row0_col1, #T_ef8fc_row0_col2, #T_ef8fc_row0_col4, #T_ef8fc_row0_col5, #T_ef8fc_row2_col1, #T_ef8fc_row2_col3, #T_ef8fc_row2_col4, #T_ef8fc_row2_col5, #T_ef8fc_row3_col2, #T_ef8fc_row3_col5, #T_ef8fc_row4_col1, #T_ef8fc_row4_col3, #T_ef8fc_row4_col4, #T_ef8fc_row5_col2, #T_ef8fc_row5_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ef8fc_row1_col3 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_ef8fc_row1_col4, #T_ef8fc_row3_col3, #T_ef8fc_row4_col2, #T_ef8fc_row5_col1, #T_ef8fc_row5_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ef8fc_row1_col5 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_ef8fc_row2_col2 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_ef8fc_row3_col1 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_ef8fc_row3_col4 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ef8fc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="6">best_val_categorical_accuracy</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >new_rank</th>
#       <th class="col_heading level1 col0" >1</th>
#       <th class="col_heading level1 col1" >4</th>
#       <th class="col_heading level1 col2" >14</th>
#       <th class="col_heading level1 col3" >53</th>
#       <th class="col_heading level1 col4" >200</th>
#       <th class="col_heading level1 col5" >256</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >initial_rank</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef8fc_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ef8fc_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_ef8fc_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_ef8fc_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_ef8fc_row0_col3" class="data row0 col3" >0.755</td>
#       <td id="T_ef8fc_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_ef8fc_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ef8fc_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_ef8fc_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_ef8fc_row1_col1" class="data row1 col1" >0.732</td>
#       <td id="T_ef8fc_row1_col2" class="data row1 col2" >0.766</td>
#       <td id="T_ef8fc_row1_col3" class="data row1 col3" >0.773</td>
#       <td id="T_ef8fc_row1_col4" class="data row1 col4" >0.783</td>
#       <td id="T_ef8fc_row1_col5" class="data row1 col5" >0.782</td>
#     </tr>
#     <tr>
#       <th id="T_ef8fc_level0_row2" class="row_heading level0 row2" >14</th>
#       <td id="T_ef8fc_row2_col0" class="data row2 col0" >0.674</td>
#       <td id="T_ef8fc_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_ef8fc_row2_col2" class="data row2 col2" >0.779</td>
#       <td id="T_ef8fc_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_ef8fc_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_ef8fc_row2_col5" class="data row2 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ef8fc_level0_row3" class="row_heading level0 row3" >53</th>
#       <td id="T_ef8fc_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_ef8fc_row3_col1" class="data row3 col1" >0.738</td>
#       <td id="T_ef8fc_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_ef8fc_row3_col3" class="data row3 col3" >0.774</td>
#       <td id="T_ef8fc_row3_col4" class="data row3 col4" >0.780</td>
#       <td id="T_ef8fc_row3_col5" class="data row3 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ef8fc_level0_row4" class="row_heading level0 row4" >200</th>
#       <td id="T_ef8fc_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_ef8fc_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_ef8fc_row4_col2" class="data row4 col2" >0.784</td>
#       <td id="T_ef8fc_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_ef8fc_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_ef8fc_row4_col5" class="data row4 col5" >0.778</td>
#     </tr>
#     <tr>
#       <th id="T_ef8fc_level0_row5" class="row_heading level0 row5" >256</th>
#       <td id="T_ef8fc_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_ef8fc_row5_col1" class="data row5 col1" >0.739</td>
#       <td id="T_ef8fc_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_ef8fc_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_ef8fc_row5_col4" class="data row5 col4" >0.773</td>
#       <td id="T_ef8fc_row5_col5" class="data row5 col5" >0.790</td>
#     </tr>
#   </tbody>
# </table>
# Rank updated on epoch: 25
# <style type="text/css">
# #T_a0271_row0_col0, #T_a0271_row0_col1, #T_a0271_row0_col5, #T_a0271_row1_col3, #T_a0271_row2_col1, #T_a0271_row3_col0, #T_a0271_row3_col1, #T_a0271_row5_col1, #T_a0271_row5_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a0271_row0_col2, #T_a0271_row0_col3, #T_a0271_row0_col4, #T_a0271_row1_col0, #T_a0271_row1_col1, #T_a0271_row1_col2, #T_a0271_row1_col4, #T_a0271_row1_col5, #T_a0271_row2_col2, #T_a0271_row2_col4, #T_a0271_row3_col2, #T_a0271_row3_col4, #T_a0271_row4_col2, #T_a0271_row4_col4, #T_a0271_row5_col2, #T_a0271_row5_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a0271_row2_col0 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_a0271_row2_col3 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_a0271_row2_col5 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_a0271_row3_col3 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_a0271_row3_col5 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_a0271_row4_col0, #T_a0271_row4_col1, #T_a0271_row4_col3, #T_a0271_row4_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a0271_row5_col0 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_a0271_row5_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a0271_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="6">best_val_categorical_accuracy</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >new_rank</th>
#       <th class="col_heading level1 col0" >1</th>
#       <th class="col_heading level1 col1" >4</th>
#       <th class="col_heading level1 col2" >14</th>
#       <th class="col_heading level1 col3" >53</th>
#       <th class="col_heading level1 col4" >200</th>
#       <th class="col_heading level1 col5" >256</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >initial_rank</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0271_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a0271_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_a0271_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_a0271_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_a0271_row0_col3" class="data row0 col3" >0.705</td>
#       <td id="T_a0271_row0_col4" class="data row0 col4" >0.710</td>
#       <td id="T_a0271_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a0271_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_a0271_row1_col0" class="data row1 col0" >0.714</td>
#       <td id="T_a0271_row1_col1" class="data row1 col1" >0.739</td>
#       <td id="T_a0271_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_a0271_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_a0271_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_a0271_row1_col5" class="data row1 col5" >0.762</td>
#     </tr>
#     <tr>
#       <th id="T_a0271_level0_row2" class="row_heading level0 row2" >14</th>
#       <td id="T_a0271_row2_col0" class="data row2 col0" >0.766</td>
#       <td id="T_a0271_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_a0271_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_a0271_row2_col3" class="data row2 col3" >0.780</td>
#       <td id="T_a0271_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_a0271_row2_col5" class="data row2 col5" >0.776</td>
#     </tr>
#     <tr>
#       <th id="T_a0271_level0_row3" class="row_heading level0 row3" >53</th>
#       <td id="T_a0271_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_a0271_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_a0271_row3_col2" class="data row3 col2" >0.780</td>
#       <td id="T_a0271_row3_col3" class="data row3 col3" >0.777</td>
#       <td id="T_a0271_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_a0271_row3_col5" class="data row3 col5" >0.778</td>
#     </tr>
#     <tr>
#       <th id="T_a0271_level0_row4" class="row_heading level0 row4" >200</th>
#       <td id="T_a0271_row4_col0" class="data row4 col0" >0.779</td>
#       <td id="T_a0271_row4_col1" class="data row4 col1" >0.776</td>
#       <td id="T_a0271_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_a0271_row4_col3" class="data row4 col3" >0.788</td>
#       <td id="T_a0271_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_a0271_row4_col5" class="data row4 col5" >0.780</td>
#     </tr>
#     <tr>
#       <th id="T_a0271_level0_row5" class="row_heading level0 row5" >256</th>
#       <td id="T_a0271_row5_col0" class="data row5 col0" >0.771</td>
#       <td id="T_a0271_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_a0271_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_a0271_row5_col3" class="data row5 col3" >0.776</td>
#       <td id="T_a0271_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_a0271_row5_col5" class="data row5 col5" >nan</td>
#     </tr>
#   </tbody>
# </table>
